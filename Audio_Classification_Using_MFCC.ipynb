# %% [markdown]
# <a href="https://colab.research.google.com/github/Hani1-2/DeepLearningAssignmnt/blob/master/Audio_Classification_Using_MFCC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Load Data

# %%
import json
import numpy as np
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import tensorflow.keras as keras

# path to json file that stores MFCCs and genre labels for each processed segment
DATA_PATH = "/content/data_surah_1.json"

def load_data(data_path):
    """Loads training dataset from json file.
        :param data_path (str): Path to json file containing data
        :return X (ndarray): Inputs
        :return y (ndarray): Targets
    """

    with open(data_path, "r") as fp:
        data = json.load(fp)

    # convert lists to numpy arrays
    X = np.array(data["mfcc"])
    y = np.array(data["labels"])

    print("Data succesfully loaded!")

    return  X, y

# %% [markdown]
# # Plot History

# %%
def plot_history(history):
    """Plots accuracy/loss for training/validation set as a function of the epochs
        :param history: Training history of model
        :return:
    """

    fig, axs = plt.subplots(2)

    # create accuracy sublpot
    axs[0].plot(history.history["accuracy"], label="train accuracy")
    axs[0].plot(history.history["val_accuracy"], label="test accuracy")
    axs[0].set_ylabel("Accuracy")
    axs[0].legend(loc="lower right")
    axs[0].set_title("Accuracy eval")

    # create error sublpot
    axs[1].plot(history.history["loss"], label="train error")
    axs[1].plot(history.history["val_loss"], label="test error")
    axs[1].set_ylabel("Error")
    axs[1].set_xlabel("Epoch")
    axs[1].legend(loc="upper right")
    axs[1].set_title("Error eval")

    plt.show()

# %% [markdown]
# # Prepare Dataset

# %%
def prepare_datasets(test_size, validation_size):
    """Loads data and splits it into train, validation and test sets.
    :param test_size (float): Value in [0, 1] indicating percentage of data set to allocate to test split
    :param validation_size (float): Value in [0, 1] indicating percentage of train set to allocate to validation split
    :return X_train (ndarray): Input training set
    :return X_validation (ndarray): Input validation set
    :return X_test (ndarray): Input test set
    :return y_train (ndarray): Target training set
    :return y_validation (ndarray): Target validation set
    :return y_test (ndarray): Target test set
    """

    # load data
    X, y = load_data(DATA_PATH)

    # create train, validation and test split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size)
    X_train, X_validation, y_train, y_validation = train_test_split(X_train, y_train, test_size=validation_size)

    # add an axis to input sets
    X_train = X_train[..., np.newaxis]
    X_validation = X_validation[..., np.newaxis]
    X_test = X_test[..., np.newaxis]

    return X_train, X_validation, X_test, y_train, y_validation, y_test

# %% [markdown]
# # Build Model

# %%
def build_model(input_shape):
    """Generates CNN model
    :param input_shape (tuple): Shape of input set
    :return model: CNN model
    """

    # build network topology
    model = keras.Sequential()

    # 1st conv layer
    model.add(keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=input_shape))
    model.add(keras.layers.MaxPooling2D((3, 3), strides=(2, 2), padding='same'))
    model.add(keras.layers.BatchNormalization())

    # 2nd conv layer
    model.add(keras.layers.Conv2D(64, (3, 3), activation='relu'))
    model.add(keras.layers.MaxPooling2D((3, 3), strides=(2, 2), padding='same'))
    model.add(keras.layers.BatchNormalization())

    # # 3rd conv layer
    # model.add(keras.layers.Conv2D(128, (2, 2), activation='relu'))
    # model.add(keras.layers.MaxPooling2D((2, 2), strides=(2, 2), padding='same'))
    # model.add(keras.layers.BatchNormalization())

    # flatten output and feed it into dense layer
    model.add(keras.layers.Flatten())
    model.add(keras.layers.Dense(256, activation='relu'))
    model.add(keras.layers.Dropout(0.2))

    # output layer
    model.add(keras.layers.Dense(28, activation='softmax'))

    return model

# %%
def predict(model, X, y):
    """Predict a single sample using the trained model
    :param model: Trained classifier
    :param X: Input data
    :param y (int): Target
    """

    # add a dimension to input data for sample - model.predict() expects a 4d array in this case
    X = X[np.newaxis, ...] # array shape (1, 130, 13, 1)

    # perform prediction
    prediction = model.predict(X)

    # get index with max value
    predicted_index = np.argmax(prediction, axis=1)

    print("Target: {}, Predicted label: {}".format(y, predicted_index))

# %%
if __name__ == "__main__":

    # get train, validation, test splits
    X_train, X_validation, X_test, y_train, y_validation, y_test = prepare_datasets(0.25, 0.2)
    # create network
    input_shape = (X_train.shape[1], X_train.shape[2], 1)
    model = build_model(input_shape)

    # compile model
    optimiser = keras.optimizers.Adam(learning_rate=0.0001)
    model.compile(optimizer=optimiser,
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])

    model.summary()

    # train model
    history = model.fit(X_train, y_train, validation_data=(X_validation, y_validation), batch_size=32, epochs=100)

    # plot accuracy/error for training and validation
    plot_history(history)

    # evaluate model on test set
    test_loss, test_acc = model.evaluate(X_test, y_test, verbose=2)
    print('\nTest accuracy:', test_acc)
# Out:
# Data succesfully loaded!
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_7 (Conv2D)           (None, 7, 11, 32)         320
#
#  max_pooling2d_6 (MaxPooling  (None, 4, 6, 32)         0
#  2D)
#
#  batch_normalization_6 (Batc  (None, 4, 6, 32)         128
#  hNormalization)
#
#  conv2d_8 (Conv2D)           (None, 2, 4, 64)          18496
#
#  max_pooling2d_7 (MaxPooling  (None, 1, 2, 64)         0
#  2D)
#
#  batch_normalization_7 (Batc  (None, 1, 2, 64)         256
#  hNormalization)
#
#  flatten_2 (Flatten)         (None, 128)               0
#
#  dense_4 (Dense)             (None, 256)               33024
#
#  dropout_2 (Dropout)         (None, 256)               0
#
#  dense_5 (Dense)             (None, 28)                7196
#
# =================================================================
# Total params: 59,420
# Trainable params: 59,228
# Non-trainable params: 192
# _________________________________________________________________
# Epoch 1/100
# 75/75 [==============================] - 3s 10ms/step - loss: 3.4193 - accuracy: 0.0667 - val_loss: 3.3878 - val_accuracy: 0.0467
# Epoch 2/100
# 75/75 [==============================] - 0s 5ms/step - loss: 3.1480 - accuracy: 0.1225 - val_loss: 3.1197 - val_accuracy: 0.1217
# Epoch 3/100
# 75/75 [==============================] - 0s 5ms/step - loss: 3.0130 - accuracy: 0.1342 - val_loss: 2.9900 - val_accuracy: 0.1567
# Epoch 4/100
# 75/75 [==============================] - 0s 5ms/step - loss: 2.9239 - accuracy: 0.1567 - val_loss: 2.9103 - val_accuracy: 0.1583
# Epoch 5/100
# 75/75 [==============================] - 0s 5ms/step - loss: 2.8443 - accuracy: 0.1750 - val_loss: 2.8508 - val_accuracy: 0.1667
# Epoch 6/100
# 75/75 [==============================] - 0s 5ms/step - loss: 2.7906 - accuracy: 0.1825 - val_loss: 2.7908 - val_accuracy: 0.1717
# Epoch 7/100
# 75/75 [==============================] - 0s 5ms/step - loss: 2.7300 - accuracy: 0.1937 - val_loss: 2.7506 - val_accuracy: 0.1967
# Epoch 8/100
# 75/75 [==============================] - 1s 7ms/step - loss: 2.6608 - accuracy: 0.2071 - val_loss: 2.7164 - val_accuracy: 0.2017
# Epoch 9/100
# 75/75 [==============================] - 1s 8ms/step - loss: 2.6138 - accuracy: 0.2350 - val_loss: 2.6819 - val_accuracy: 0.1967
# Epoch 10/100
# 75/75 [==============================] - 1s 8ms/step - loss: 2.5617 - accuracy: 0.2483 - val_loss: 2.6477 - val_accuracy: 0.2100
# Epoch 11/100
# 75/75 [==============================] - 0s 6ms/step - loss: 2.5090 - accuracy: 0.2537 - val_loss: 2.6202 - val_accuracy: 0.2333
# Epoch 12/100
# 75/75 [==============================] - 0s 5ms/step - loss: 2.4763 - accuracy: 0.2617 - val_loss: 2.5989 - val_accuracy: 0.2350
# Epoch 13/100
# 75/75 [==============================] - 0s 5ms/step - loss: 2.4465 - accuracy: 0.2667 - val_loss: 2.5792 - val_accuracy: 0.2183
# Epoch 14/100
# 75/75 [==============================] - 0s 5ms/step - loss: 2.3981 - accuracy: 0.2783 - val_loss: 2.5533 - val_accuracy: 0.2350
# Epoch 15/100
# 75/75 [==============================] - 0s 5ms/step - loss: 2.3661 - accuracy: 0.2792 - val_loss: 2.5296 - val_accuracy: 0.2317
# Epoch 16/100
# 75/75 [==============================] - 0s 5ms/step - loss: 2.3324 - accuracy: 0.3004 - val_loss: 2.5093 - val_accuracy: 0.2350
# Epoch 17/100
# 75/75 [==============================] - 0s 5ms/step - loss: 2.2918 - accuracy: 0.3033 - val_loss: 2.4964 - val_accuracy: 0.2483
# Epoch 18/100
# 75/75 [==============================] - 0s 5ms/step - loss: 2.2432 - accuracy: 0.3200 - val_loss: 2.4748 - val_accuracy: 0.2567
# Epoch 19/100
# 75/75 [==============================] - 0s 5ms/step - loss: 2.2137 - accuracy: 0.3212 - val_loss: 2.4626 - val_accuracy: 0.2667
# Epoch 20/100
# 75/75 [==============================] - 0s 5ms/step - loss: 2.1998 - accuracy: 0.3371 - val_loss: 2.4431 - val_accuracy: 0.2750
# Epoch 21/100
# 75/75 [==============================] - 0s 5ms/step - loss: 2.1463 - accuracy: 0.3500 - val_loss: 2.4249 - val_accuracy: 0.2633
# Epoch 22/100
# 75/75 [==============================] - 0s 5ms/step - loss: 2.1215 - accuracy: 0.3504 - val_loss: 2.4138 - val_accuracy: 0.2667
# Epoch 23/100
# 75/75 [==============================] - 0s 5ms/step - loss: 2.0928 - accuracy: 0.3704 - val_loss: 2.3986 - val_accuracy: 0.2867
# Epoch 24/100
# 75/75 [==============================] - 0s 5ms/step - loss: 2.0695 - accuracy: 0.3758 - val_loss: 2.3905 - val_accuracy: 0.2950
# Epoch 25/100
# 75/75 [==============================] - 0s 5ms/step - loss: 2.0319 - accuracy: 0.3767 - val_loss: 2.3781 - val_accuracy: 0.2833
# Epoch 26/100
# 75/75 [==============================] - 0s 5ms/step - loss: 2.0015 - accuracy: 0.3858 - val_loss: 2.3647 - val_accuracy: 0.2917
# Epoch 27/100
# 75/75 [==============================] - 0s 5ms/step - loss: 1.9642 - accuracy: 0.4067 - val_loss: 2.3508 - val_accuracy: 0.3017
# Epoch 28/100
# 75/75 [==============================] - 0s 5ms/step - loss: 1.9374 - accuracy: 0.4187 - val_loss: 2.3430 - val_accuracy: 0.2950
# Epoch 29/100
# 75/75 [==============================] - 0s 5ms/step - loss: 1.9227 - accuracy: 0.4175 - val_loss: 2.3288 - val_accuracy: 0.2950
# Epoch 30/100
# 75/75 [==============================] - 0s 5ms/step - loss: 1.8863 - accuracy: 0.4325 - val_loss: 2.3238 - val_accuracy: 0.3100
# Epoch 31/100
# 75/75 [==============================] - 0s 5ms/step - loss: 1.8650 - accuracy: 0.4342 - val_loss: 2.3088 - val_accuracy: 0.3067
# Epoch 32/100
# 75/75 [==============================] - 0s 5ms/step - loss: 1.8323 - accuracy: 0.4517 - val_loss: 2.3026 - val_accuracy: 0.2983
# Epoch 33/100
# 75/75 [==============================] - 0s 5ms/step - loss: 1.7954 - accuracy: 0.4663 - val_loss: 2.3011 - val_accuracy: 0.2950
# Epoch 34/100
# 75/75 [==============================] - 0s 5ms/step - loss: 1.7851 - accuracy: 0.4487 - val_loss: 2.2849 - val_accuracy: 0.3033
# Epoch 35/100
# 75/75 [==============================] - 0s 5ms/step - loss: 1.7647 - accuracy: 0.4700 - val_loss: 2.2784 - val_accuracy: 0.2967
# Epoch 36/100
# 75/75 [==============================] - 0s 5ms/step - loss: 1.7351 - accuracy: 0.4875 - val_loss: 2.2782 - val_accuracy: 0.3050
# Epoch 37/100
# 75/75 [==============================] - 0s 5ms/step - loss: 1.7263 - accuracy: 0.4888 - val_loss: 2.2661 - val_accuracy: 0.3083
# Epoch 38/100
# 75/75 [==============================] - 1s 7ms/step - loss: 1.6802 - accuracy: 0.4913 - val_loss: 2.2519 - val_accuracy: 0.3167
# Epoch 39/100
# 75/75 [==============================] - 1s 8ms/step - loss: 1.6467 - accuracy: 0.5108 - val_loss: 2.2587 - val_accuracy: 0.3083
# Epoch 40/100
# 75/75 [==============================] - 1s 7ms/step - loss: 1.6173 - accuracy: 0.5196 - val_loss: 2.2459 - val_accuracy: 0.3067
# Epoch 41/100
# 75/75 [==============================] - 1s 7ms/step - loss: 1.6071 - accuracy: 0.5183 - val_loss: 2.2529 - val_accuracy: 0.3083
# Epoch 42/100
# 75/75 [==============================] - 0s 5ms/step - loss: 1.6056 - accuracy: 0.5246 - val_loss: 2.2426 - val_accuracy: 0.3100
# Epoch 43/100
# 75/75 [==============================] - 0s 5ms/step - loss: 1.5718 - accuracy: 0.5267 - val_loss: 2.2341 - val_accuracy: 0.3183
# Epoch 44/100
# 75/75 [==============================] - 0s 5ms/step - loss: 1.5454 - accuracy: 0.5367 - val_loss: 2.2347 - val_accuracy: 0.3117
# Epoch 45/100
# 75/75 [==============================] - 0s 5ms/step - loss: 1.5302 - accuracy: 0.5362 - val_loss: 2.2193 - val_accuracy: 0.3233
# Epoch 46/100
# 75/75 [==============================] - 0s 5ms/step - loss: 1.4875 - accuracy: 0.5508 - val_loss: 2.2190 - val_accuracy: 0.3250
# Epoch 47/100
# 75/75 [==============================] - 0s 5ms/step - loss: 1.4884 - accuracy: 0.5558 - val_loss: 2.2155 - val_accuracy: 0.3183
# Epoch 48/100
# 75/75 [==============================] - 0s 5ms/step - loss: 1.4571 - accuracy: 0.5612 - val_loss: 2.2015 - val_accuracy: 0.3283
# Epoch 49/100
# 75/75 [==============================] - 0s 5ms/step - loss: 1.4325 - accuracy: 0.5650 - val_loss: 2.2140 - val_accuracy: 0.3233
# Epoch 50/100
# 75/75 [==============================] - 0s 5ms/step - loss: 1.4275 - accuracy: 0.5688 - val_loss: 2.2049 - val_accuracy: 0.3183
# Epoch 51/100
# 75/75 [==============================] - 0s 5ms/step - loss: 1.4038 - accuracy: 0.5846 - val_loss: 2.1921 - val_accuracy: 0.3267
# Epoch 52/100
# 75/75 [==============================] - 0s 5ms/step - loss: 1.4038 - accuracy: 0.5750 - val_loss: 2.1920 - val_accuracy: 0.3283
# Epoch 53/100
# 75/75 [==============================] - 0s 5ms/step - loss: 1.3495 - accuracy: 0.5938 - val_loss: 2.1843 - val_accuracy: 0.3300
# Epoch 54/100
# 75/75 [==============================] - 0s 5ms/step - loss: 1.3394 - accuracy: 0.5996 - val_loss: 2.1838 - val_accuracy: 0.3267
# Epoch 55/100
# 75/75 [==============================] - 0s 5ms/step - loss: 1.3258 - accuracy: 0.6033 - val_loss: 2.1969 - val_accuracy: 0.3233
# Epoch 56/100
# 75/75 [==============================] - 0s 5ms/step - loss: 1.2954 - accuracy: 0.6258 - val_loss: 2.1863 - val_accuracy: 0.3250
# Epoch 57/100
# 75/75 [==============================] - 0s 5ms/step - loss: 1.3089 - accuracy: 0.6083 - val_loss: 2.1903 - val_accuracy: 0.3267
# Epoch 58/100
# 75/75 [==============================] - 0s 5ms/step - loss: 1.2686 - accuracy: 0.6321 - val_loss: 2.1876 - val_accuracy: 0.3333
# Epoch 59/100
# 75/75 [==============================] - 0s 5ms/step - loss: 1.2716 - accuracy: 0.6263 - val_loss: 2.1919 - val_accuracy: 0.3317
# Epoch 60/100
# 75/75 [==============================] - 0s 5ms/step - loss: 1.2376 - accuracy: 0.6321 - val_loss: 2.1961 - val_accuracy: 0.3183
# Epoch 61/100
# 75/75 [==============================] - 0s 5ms/step - loss: 1.1981 - accuracy: 0.6517 - val_loss: 2.1830 - val_accuracy: 0.3300
# Epoch 62/100
# 75/75 [==============================] - 0s 5ms/step - loss: 1.1996 - accuracy: 0.6404 - val_loss: 2.1873 - val_accuracy: 0.3317
# Epoch 63/100
# 75/75 [==============================] - 0s 5ms/step - loss: 1.2038 - accuracy: 0.6521 - val_loss: 2.1994 - val_accuracy: 0.3233
# Epoch 64/100
# 75/75 [==============================] - 0s 5ms/step - loss: 1.1761 - accuracy: 0.6546 - val_loss: 2.2012 - val_accuracy: 0.3250
# Epoch 65/100
# 75/75 [==============================] - 0s 5ms/step - loss: 1.1452 - accuracy: 0.6621 - val_loss: 2.1893 - val_accuracy: 0.3400
# Epoch 66/100
# 75/75 [==============================] - 0s 5ms/step - loss: 1.1321 - accuracy: 0.6662 - val_loss: 2.1839 - val_accuracy: 0.3200
# Epoch 67/100
# 75/75 [==============================] - 0s 5ms/step - loss: 1.1232 - accuracy: 0.6721 - val_loss: 2.1973 - val_accuracy: 0.3333
# Epoch 68/100
# 75/75 [==============================] - 0s 5ms/step - loss: 1.1088 - accuracy: 0.6804 - val_loss: 2.1963 - val_accuracy: 0.3283
# Epoch 69/100
# 75/75 [==============================] - 1s 7ms/step - loss: 1.0521 - accuracy: 0.6963 - val_loss: 2.2071 - val_accuracy: 0.3183
# Epoch 70/100
# 75/75 [==============================] - 1s 7ms/step - loss: 1.0873 - accuracy: 0.6683 - val_loss: 2.1911 - val_accuracy: 0.3350
# Epoch 71/100
# 75/75 [==============================] - 1s 7ms/step - loss: 1.0465 - accuracy: 0.6992 - val_loss: 2.2083 - val_accuracy: 0.3267
# Epoch 72/100
# 75/75 [==============================] - 1s 8ms/step - loss: 1.0468 - accuracy: 0.6867 - val_loss: 2.2037 - val_accuracy: 0.3417
# Epoch 73/100
# 75/75 [==============================] - 0s 5ms/step - loss: 1.0242 - accuracy: 0.6925 - val_loss: 2.2167 - val_accuracy: 0.3450
# Epoch 74/100
# 75/75 [==============================] - 0s 5ms/step - loss: 1.0112 - accuracy: 0.7029 - val_loss: 2.2195 - val_accuracy: 0.3267
# Epoch 75/100
# 75/75 [==============================] - 0s 5ms/step - loss: 0.9906 - accuracy: 0.7075 - val_loss: 2.2308 - val_accuracy: 0.3167
# Epoch 76/100
# 75/75 [==============================] - 0s 5ms/step - loss: 0.9739 - accuracy: 0.7096 - val_loss: 2.2185 - val_accuracy: 0.3400
# Epoch 77/100
# 75/75 [==============================] - 0s 5ms/step - loss: 0.9746 - accuracy: 0.7150 - val_loss: 2.2234 - val_accuracy: 0.3300
# Epoch 78/100
# 75/75 [==============================] - 0s 5ms/step - loss: 0.9405 - accuracy: 0.7262 - val_loss: 2.2143 - val_accuracy: 0.3367
# Epoch 79/100
# 75/75 [==============================] - 0s 5ms/step - loss: 0.9476 - accuracy: 0.7271 - val_loss: 2.2098 - val_accuracy: 0.3350
# Epoch 80/100
# 75/75 [==============================] - 0s 5ms/step - loss: 0.9254 - accuracy: 0.7367 - val_loss: 2.2383 - val_accuracy: 0.3200
# Epoch 81/100
# 75/75 [==============================] - 0s 5ms/step - loss: 0.9109 - accuracy: 0.7454 - val_loss: 2.2393 - val_accuracy: 0.3233
# Epoch 82/100
# 75/75 [==============================] - 0s 5ms/step - loss: 0.9081 - accuracy: 0.7375 - val_loss: 2.2438 - val_accuracy: 0.3067
# Epoch 83/100
# 75/75 [==============================] - 0s 5ms/step - loss: 0.8951 - accuracy: 0.7433 - val_loss: 2.2559 - val_accuracy: 0.3333
# Epoch 84/100
# 75/75 [==============================] - 0s 5ms/step - loss: 0.8644 - accuracy: 0.7521 - val_loss: 2.2313 - val_accuracy: 0.3250
# Epoch 85/100
# 75/75 [==============================] - 0s 5ms/step - loss: 0.8649 - accuracy: 0.7471 - val_loss: 2.2330 - val_accuracy: 0.3300
# Epoch 86/100
# 75/75 [==============================] - 0s 5ms/step - loss: 0.8596 - accuracy: 0.7504 - val_loss: 2.2512 - val_accuracy: 0.3400
# Epoch 87/100
# 75/75 [==============================] - 0s 5ms/step - loss: 0.8262 - accuracy: 0.7571 - val_loss: 2.2457 - val_accuracy: 0.3350
# Epoch 88/100
# 75/75 [==============================] - 0s 5ms/step - loss: 0.8194 - accuracy: 0.7692 - val_loss: 2.2420 - val_accuracy: 0.3250
# Epoch 89/100
# 75/75 [==============================] - 0s 5ms/step - loss: 0.8168 - accuracy: 0.7804 - val_loss: 2.2567 - val_accuracy: 0.3267
# Epoch 90/100
# 75/75 [==============================] - 0s 5ms/step - loss: 0.8197 - accuracy: 0.7604 - val_loss: 2.2721 - val_accuracy: 0.3200
# Epoch 91/100
# 75/75 [==============================] - 0s 5ms/step - loss: 0.8013 - accuracy: 0.7708 - val_loss: 2.2832 - val_accuracy: 0.3183
# Epoch 92/100
# 75/75 [==============================] - 0s 5ms/step - loss: 0.7848 - accuracy: 0.7738 - val_loss: 2.2699 - val_accuracy: 0.3167
# Epoch 93/100
# 75/75 [==============================] - 0s 5ms/step - loss: 0.7689 - accuracy: 0.7892 - val_loss: 2.2581 - val_accuracy: 0.3267
# Epoch 94/100
# 75/75 [==============================] - 0s 5ms/step - loss: 0.7492 - accuracy: 0.7854 - val_loss: 2.2776 - val_accuracy: 0.3200
# Epoch 95/100
# 75/75 [==============================] - 0s 5ms/step - loss: 0.7476 - accuracy: 0.7917 - val_loss: 2.2927 - val_accuracy: 0.3100
# Epoch 96/100
# 75/75 [==============================] - 0s 5ms/step - loss: 0.7261 - accuracy: 0.7954 - val_loss: 2.2636 - val_accuracy: 0.3367
# Epoch 97/100
# 75/75 [==============================] - 0s 5ms/step - loss: 0.7287 - accuracy: 0.8012 - val_loss: 2.3020 - val_accuracy: 0.3150
# Epoch 98/100
# 75/75 [==============================] - 0s 5ms/step - loss: 0.7057 - accuracy: 0.8058 - val_loss: 2.2875 - val_accuracy: 0.3350
# Epoch 99/100
# 75/75 [==============================] - 0s 6ms/step - loss: 0.7073 - accuracy: 0.7987 - val_loss: 2.3039 - val_accuracy: 0.3217
# Epoch 100/100
# 75/75 [==============================] - 1s 8ms/step - loss: 0.7186 - accuracy: 0.7946 - val_loss: 2.3030 - val_accuracy: 0.3483
# 32/32 - 0s - loss: 2.3234 - accuracy: 0.3237 - 121ms/epoch - 4ms/step
#
# Test accuracy: 0.32367631793022156
